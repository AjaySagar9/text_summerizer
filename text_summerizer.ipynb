# %% [markdown]
# <a href="https://colab.research.google.com/github/AjaySagar9/text_summerizer/blob/main/text_summerizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import nltk
from nltk.tokenize import sent_tokenize

nltk.download('punkt')
nltk.download('punkt_tab') # Add this line to download the missing resource

print("🤖 Text Summarizer Chatbot")

while True:
    text = input("\nEnter Text: ")

    if text.lower() == "exit":
        break

    sentences = sent_tokenize(text)

    summary = " ".join(sentences[:3])

    print("\nSummary:")
    print(summary)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 🤖 Text Summarizer Chatbot
#
# Enter Text: A fluffy ginger cat wearing a tiny business suit and reading glasses sits at an office desk. The cat is furiously typing on a laptop with its paws, looking stressed and deeply confused by the screen. The background is a chaotic office cubicle. Dramatic close-up zoom on its wide-eyed, bewildered face. Modern comedy sketch aesthetic, bright office lighting, 4k resolution.
#
# Summary:
# A fluffy ginger cat wearing a tiny business suit and reading glasses sits at an office desk. The cat is furiously typing on a laptop with its paws, looking stressed and deeply confused by the screen. The background is a chaotic office cubicle.
